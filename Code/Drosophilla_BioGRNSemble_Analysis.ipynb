# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Loading the two outputs generated by GENIE3 and GRNBoost2

# %%
genie3_df    = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/GENIE3_Ranking_TF_TG.csv', sep=',')

# %% [markdown]
# ##2. Printing dimensions and top ranked genes of each produced output

# %% [markdown]
# ### i. GENIE3

# %%
genie3_df = genie3_df.iloc[:, 3:6]
score_col = genie3_df.pop('score')
genie3_df.insert(2, 'score', round(score_col,5))

# %%
genie3_df.head(10)
# Out:
#         TF          TG    score
# 0  dmrt93B     CG14932  0.85471
# 1  dmrt93B       Gr63a  0.84326
# 2  dmrt93B     CG14955  0.83637
# 3  dmrt93B     Hsp70Aa  0.83425
# 4  dmrt93B     Hsp70Bc  0.83026
# 5    GATAe  PH4alphaPV  0.82495
# 6      fkh       MRE23  0.82274
# 7      shn     CG14471  0.81887
# 8  dmrt93B    Hsp70Bbb  0.81283
# 9  CG13510     CG13511  0.79432

# %%
genie3_df = genie3_df[(genie3_df != 0).all(1)]

# %%
genie3_df_filtered = genie3_df[(genie3_df[['score']]>=0.50).all(axis=1)]

# %%
print(len(genie3_df_filtered))
print(genie3_df_filtered['TF'].value_counts())
# Out:
# 210
# TF
# GATAe      45
# dmrt93B    44
# CG30431    18
# srp         9
# trh         9
#            ..
# CG13894     1
# cnc         1
# maf-S       1
# Rel         1
# Cf2         1
# Name: count, Length: 62, dtype: int64

# %%
len(genie3_df_filtered)
# Out:
# 210

# %%
genie3_df_filtered.head(15)
# Out:
#          TF          TG    score
# 0   dmrt93B     CG14932  0.85471
# 1   dmrt93B       Gr63a  0.84326
# 2   dmrt93B     CG14955  0.83637
# 3   dmrt93B     Hsp70Aa  0.83425
# 4   dmrt93B     Hsp70Bc  0.83026
# 5     GATAe  PH4alphaPV  0.82495
# 6       fkh       MRE23  0.82274
# 7       shn     CG14471  0.81887
# 8   dmrt93B    Hsp70Bbb  0.81283
# 9   CG13510     CG13511  0.79432
# 10      srp     CG30046  0.78697
# 11  CG13510     Tsp29Fb  0.76413
# 12  dmrt93B     Hsp70Ab  0.76267
# 13    GATAe     CG18748  0.76038
# 14    GATAe     CG30413  0.75903

# %%
genie3_df_filtered.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/genie3_GRN_40.csv')

# %%
genie3_df_filtered.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/genie3_GRN_50.csv')

# %% [markdown]
# ### Transcription Factors with most regulators
#
# i. within

# %% [markdown]
# ### ii. GRNBOOST2

# %%
GRNBoost2_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/GRNBoost2_network.tsv', sep='\t', names=['TF', 'TG', 'Score'], header = None)

# %%
GRNBoost2_df['Score'] = GRNBoost2_df['Score']/100.0

# %%
GRNBoost2_df.head(10)
# Out:
#          TF       TG     Score
# 0      TFAM    exo70  0.833288
# 1      Tsf2   CG9634  0.671760
# 2     Atf-2  CG32815  0.663000
# 3       her   CG8613  0.647054
# 4       cnc  CG15099  0.612437
# 5       ems    Hsp60  0.612328
# 6    CG1024      vir  0.611803
# 7   CG12219      wdn  0.610983
# 8  MBD-like   CG9797  0.600319
# 9      B-H2       so  0.598897

# %%
grn_filtered = GRNBoost2_df[(GRNBoost2_df[['Score']]>=0.50).all(axis=1)]

# %%
print(len(grn_filtered))
print(grn_filtered['TF'].value_counts())
# Out:
# 138
# TF
# TFAM       5
# CG2116     5
# CG11902    4
# CG10979    3
# crol       3
#           ..
# CG32772    1
# Dad        1
# awd        1
# CG13510    1
# CG2199     1
# Name: count, Length: 103, dtype: int64

# %%
grn_filtered
# Out:
#             TF       TG     Score
# 0         TFAM    exo70  0.833288
# 1         Tsf2   CG9634  0.671760
# 2        Atf-2  CG32815  0.663000
# 3          her   CG8613  0.647054
# 4          cnc  CG15099  0.612437
# ...        ...      ...       ...
# 9813  l(2)37Cc   CG6020  0.250020
# 9814    Jarid2     SRPK  0.250017
# 9815       mld  CG42671  0.250017
# 9816    CG9215     Taf8  0.250013
# 9817    CG4282   CG8417  0.250000
#
# [9818 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import plotly.express as px

grn_filtered_count = grn_filtered.groupby(['TF'])['TF'].count().reset_index(name='count')
grn_filtered_count = grn_filtered_count.sort_values(by=['count'],ascending=False).reset_index()
grn_filtered_count.head()
# Out:
#    index       TF  count
# 0     23   CG2116      5
# 1     63     TFAM      5
# 2     12  CG11902      4
# 3     79     crol      3
# 4     10  CG10979      3

# %%
fig = px.pie(grn_filtered_count[:5], values='count', names='TF', title='Most connected Transcription Factors')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c2d8329-3f84-4eef-9e61-d943e9215dc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c2d8329-3f84-4eef-9e61-d943e9215dc1")) {                    Plotly.newPlot(                        "5c2d8329-3f84-4eef-9e61-d943e9215dc1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"TF=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["CG2116","TFAM","CG11902","crol","CG10979"],"legendgroup":"","name":"","showlegend":true,"values":[5,5,4,3,3],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"h ...

# %% [markdown]
# ## 3. Gene ranking dataset created from overlapping links between GENIE3 and GRNBoost2 outputs
#
# - The resulting dataset will be termed as 'BioGRN'

# %%
grn_final = pd.merge(genie3_df, GRNBoost2_df, how='inner', on=['TF','TG'])

# %%
grn_final_filtered = pd.merge(genie3_df_filtered, grn_filtered, how='inner', on=['TF','TG'])

# %%
grn_final = grn_final.rename(columns={"score": "genie3_score", "Score": "GRNBoost2_score"})

# %%
grn_final.head(10)
# Out:
#   Unnamed: 0  Unnamed: 1  rank  genie3_score       TF          TG  \
# 0    dmrt93B     CG14932   1.0      0.854713  dmrt93B     CG14932
# 1    dmrt93B       Gr63a   2.0      0.843259  dmrt93B       Gr63a
# 2    dmrt93B     CG14955   3.0      0.836367  dmrt93B     CG14955
# 3    dmrt93B     Hsp70Aa   4.0      0.834249  dmrt93B     Hsp70Aa
# 4    dmrt93B     Hsp70Bc   5.0      0.830264  dmrt93B     Hsp70Bc
# 5      GATAe  PH4alphaPV   6.0      0.824947    GATAe  PH4alphaPV
# 6        fkh       MRE23   7.0      0.822737      fkh       MRE23
# 7        shn     CG14471   8.0      0.818870      shn     CG14471
# 8    dmrt93B    Hsp70Bbb   9.0      0.812825  dmrt93B    Hsp70Bbb
# 9    CG13510     CG13511  10.0      0.794322  CG13510     CG13511
#
#    GRNBoost2_score
# 0        35.982913
# 1        42.867362
# 2        26.452926
# 3        35.178831
# 4        34.699198
# 5        24.080847
# 6        40.866506
# 7        41.174992
# 8        24.960379
# 9        55.063971

# %%
grn_final['Average Score'] = (grn_final['genie3_score']+grn_final['GRNBoost2_score'])/2
grn_final['Score difference'] = abs(grn_final['genie3_score']-grn_final['GRNBoost2_score'])

# %%
grn_final.head(100)
# Out:
#    Unnamed: 0 Unnamed: 1   rank  genie3_score       TF       TG  \
# 0     dmrt93B    CG14932    1.0      0.854713  dmrt93B  CG14932
# 1     dmrt93B      Gr63a    2.0      0.843259  dmrt93B    Gr63a
# 2     dmrt93B    CG14955    3.0      0.836367  dmrt93B  CG14955
# 3     dmrt93B    Hsp70Aa    4.0      0.834249  dmrt93B  Hsp70Aa
# 4     dmrt93B    Hsp70Bc    5.0      0.830264  dmrt93B  Hsp70Bc
# ..        ...        ...    ...           ...      ...      ...
# 95    dmrt93B      Hsp68   96.0      0.593958  dmrt93B    Hsp68
# 96       sage    CG43084   97.0      0.593677     sage  CG43084
# 97      GATAe    CG15818   98.0      0.593651    GATAe  CG15818
# 98         tx     CG9194   99.0      0.592643       tx   CG9194
# 99    dmrt93B     CG2681  100.0      0.591385  dmrt93B   CG2681
#
#     GRNBoost2_score  Average Score  Score difference
# 0         35.982913      18.418813         35.128199
# 1         42.867362      21.855310         42.024103
# 2         26.452926      13.644647         25.616559
# 3         35.178831      18.006540         34.344581
# 4         34.699198      17.764731         33.868934
# ..              ...            ...               ...
# 95        30.602970      15.598464         30.009012
# 96        18.570494       9.582086         17.976817
# 97        20.187727      10.390689         19.594076
# 98        11.156582       5.874612         10.563939
# 99        13.097511       6.844448         12.506125
#
# [100 rows x 9 columns]

# %%
grn_final_sort = grn_final.sort_values(by=['Average Score'],ascending=False).reset_index()
grn_final_sort.head(10)
# Out:
#    index       TF       TG  genie3_score  GRNBoost2_score  Average Score  \
# 0      9  CG13510  CG13511       0.79432         0.550640       0.672480
# 1     22  dmrt93B  CG13138       0.72797         0.588344       0.658157
# 2     19     salm     salr       0.74189         0.540694       0.641292
# 3      1  dmrt93B    Gr63a       0.84326         0.428674       0.635967
# 4      6      fkh    MRE23       0.82274         0.408665       0.615703
# 5      7      shn  CG14471       0.81887         0.411750       0.615310
# 6      0  dmrt93B  CG14932       0.85471         0.359829       0.607270
# 7     36      Jra  CG14207       0.68480         0.524429       0.604615
# 8     10      srp  CG30046       0.78697         0.399444       0.593207
# 9      3  dmrt93B  Hsp70Aa       0.83425         0.351788       0.593019
#
#    Score difference
# 0          0.243680
# 1          0.139626
# 2          0.201196
# 3          0.414586
# 4          0.414075
# 5          0.407120
# 6          0.494881
# 7          0.160371
# 8          0.387526
# 9          0.482462

# %%
grn_final_filtered = grn_final[(grn_final[['Average Score']]>=0.50).all(axis=1)]

# %%
grn_final_filtered
# Out:
#           TF          TG  genie3_score  GRNBoost2_score  Average Score  \
# 0    dmrt93B     CG14932       0.85471         0.359829       0.607270
# 1    dmrt93B       Gr63a       0.84326         0.428674       0.635967
# 2    dmrt93B     CG14955       0.83637         0.264529       0.550450
# 3    dmrt93B     Hsp70Aa       0.83425         0.351788       0.593019
# 4    dmrt93B     Hsp70Bc       0.83026         0.346992       0.588626
# 5      GATAe  PH4alphaPV       0.82495         0.240808       0.532879
# 6        fkh       MRE23       0.82274         0.408665       0.615703
# 7        shn     CG14471       0.81887         0.411750       0.615310
# 8    dmrt93B    Hsp70Bbb       0.81283         0.249604       0.531217
# 9    CG13510     CG13511       0.79432         0.550640       0.672480
# 10       srp     CG30046       0.78697         0.399444       0.593207
# 11   CG13510     Tsp29Fb       0.76413         0.299263       0.531697
# 12   dmrt93B     Hsp70Ab       0.76267         0.352068       0.557369
# 15   dmrt93B       Ucp4C       0.75777         0.337097       0.547433
# 18   dmrt93B         fan       0.74611         0.312223       0.529166
# 19      salm        salr       0.74189         0.540694       0.641292
# 21   dmrt93B       Hsp26       0.73923         0.428982       0.584106
# 22   dmrt93B     CG13138       0.72797         0.588344       0.658157
# 23        kn          ap       0.71790         0.330328       0.524114
# 25     GATAe     CG34236       0.70733         0.344572       0.525951
# 26      sage     CG43083       0.70544         0.405150       0.555295
# 27   dmrt93B         stv       0.70528         0.383908       0.544594
# 28       bap     CG13227       0.70335         0.439024       0.571187
# 32   CG30269     CG30273       0.69323         0.352315       0.522773
# 36       Jra     CG14207       0.68480         0.524429       0.604615
# 39       tll        gcm2       0.68012         0.474921       0.577521
# 41     GATAe      CG8952       0.67632         0.334885       0.505603
# 53    CG3281         aur       0.66101         0.409503       0.535256
# 82       Zif       jigr1       0.61072         0.429611       0.520166
# 121      trh        Antp       0.56502         0.436770       0.500895
#
#      Score difference
# 0            0.247440
# 1            0.207293
# 2            0.285920
# 3            0.241231
# 4            0.241634
# 5            0.292071
# 6            0.207037
# 7            0.203560
# 8            0.281613
# 9            0.121840
# 10           0.193763
# 11           0.232433
# 12           0.205301
# 15           0.210337
# 18           0.216944
# 19           0.100598
# 21           0.155124
# 22           0.069813
# 23           0.193786
# 25           0.181379
# 26           0.150145
# 27           0.160686
# 28           0.132163
# 32           0.170457
# 36           0.080185
# 39           0.102599
# 41           0.170717
# 53           0.125754
# 82           0.090554
# 121          0.064125

# %%
grn_final_filtered.head()
# Out:
#         TF       TG    score      Score
# 0  dmrt93B    Gr63a  0.84326  42.867362
# 1      fkh    MRE23  0.82274  40.866506
# 2      shn  CG14471  0.81887  41.174992
# 3  CG13510  CG13511  0.79432  55.063971
# 4     salm     salr  0.74189  54.069407

# %%
grn_final.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/BioGRN_All.csv')

# %%
grn_filtered.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/GRNBoost_50.csv')

# %%
grn_final_filtered.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/grn_final_50.csv')

# %%
print(len(grn_final_filtered))
print(grn_final_filtered['TF'].value_counts())
# Out:
# 30
# TF
# dmrt93B    12
# GATAe       3
# CG13510     2
# fkh         1
# shn         1
# srp         1
# salm        1
# kn          1
# sage        1
# bap         1
# CG30269     1
# Jra         1
# tll         1
# CG3281      1
# Zif         1
# trh         1
# Name: count, dtype: int64

# %% [markdown]
# ### Loading TFLink dataset and comparing it with the bioGRN dataset for rough accuracy
#
# - Accuracy: The number of correctly predicted interaction links between each gene
#  A caveat of this comparison is that many predictions that dont exist in TFLink may or may not be valid, undiscovered links as well. More literature an research is definitely needed to study regulatory gene-gene interactions.

# %%
bioGRN    = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/BioGRN_All.csv', sep=',')
tfLink_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/TFLINK_Drosophila.tsv', sep='\t')

# %%
tfLink_df.head()
# Out:
#   UniprotID.TF UniprotID.Target NCBI.GeneID.TF NCBI.GeneID.Target Name.TF  \
# 0       P02836           P02836          36240              36240      en
# 1       O61735           P49021          38872              33571     Clk
# 2       Q9VN10           P39770          40549              34569     hkb
# 3       Q9XTP7           A1Z877          41265              36089    jumu
# 4       P02836           P07713          36240              33432      en
#
#   Name.Target                                   Detection.method  \
# 0          en  DNase I footprinting;chromatin immunoprecipita...
# 1         tim  chromatin immunoprecipitation assay;experiment...
# 2        salm           DNase I footprinting;inferred by curator
# 3         Ndg               electrophoretic mobility shift assay
# 4         dpp  DNase I footprinting;chromatin immunoprecipita...
#
#                                      PubmedID                 Organism  \
# 0  2895896;26578589;20965965;27924024;2573829  Drosophila melanogaster
# 1                   9616122;20965965;27924024  Drosophila melanogaster
# 2                   20965965;9376314;26578589  Drosophila melanogaster
# 3                           20965965;22378636  Drosophila melanogaster
# 4          7713429;20965965;26578589;27924024  Drosophila melanogaster
#
#         Source.database Small-scale.evidence      TF.TFLink.ortho  \
# 0  GTRD;ORegAnno;REDfly                  Yes                    -
# 1           GTRD;REDfly                  Yes  Dr:Q5RIV1;Rn:F1LRL5
# 2       ORegAnno;REDfly                  Yes                    -
# 3                REDfly                  Yes                    -
# 4  GTRD;ORegAnno;REDfly                  Yes                    -
#
#   TF.nonTFLink.ortho                                Target.TFLink.ortho  \
# 0                  -                                                  -
# 1                  -                                                  -
# 2                  -                                          Hs:Q9BXA9
# 3                  -  Hs:Q14112;Hs:P14543;Ce:Q93791;Dr:A0A0G2L836;Mm...
# 4                  -                                          Dr:O93369
#
#         Target.nonTFLink.ortho
# 0                            -
# 1                            -
# 2  Dr:A0A1D5NSE4;Mm:A0A5F8MPC9
# 3          Dr:X1WC52;Dr:Q5RI93
# 4                            -

# %%
tfLink_df2 = tfLink_df.iloc[:,4:6]

# %%
tfLink_df2.shape
# Out:
# (368629, 2)

# %%
bioGRN.shape
# Out:
# (534843, 7)

# %%
tfLink_df2 = tfLink_df2.rename(columns={"Name.TF": "TF", "Name.Target": "TG"})

# %%
tfLink_df2.head()
# Out:
#      TF    TG
# 0    en    en
# 1   Clk   tim
# 2   hkb  salm
# 3  jumu   Ndg
# 4    en   dpp

# %%
'trh' in tfLink_df2['TF']
# Out:
# False

# %%
grn_validate = pd.merge(bioGRN, tfLink_df2, how='inner', on=['TF','TG'])
grn_validate = grn_validate.iloc[:, 1:]

# %%
bioGRN['validation']= bioGRN[['TF','TG']].apply(tuple, axis=1)\
                  .isin(tfLink_df2[['TF','TG']].apply(tuple, axis=1))
bioGRN.head()
# Out:
#    Unnamed: 0       TF       TG  genie3_score  GRNBoost2_score  Average Score  \
# 0           0  dmrt93B  CG14932       0.85471         0.359829       0.607270
# 1           1  dmrt93B    Gr63a       0.84326         0.428674       0.635967
# 2           2  dmrt93B  CG14955       0.83637         0.264529       0.550450
# 3           3  dmrt93B  Hsp70Aa       0.83425         0.351788       0.593019
# 4           4  dmrt93B  Hsp70Bc       0.83026         0.346992       0.588626
#
#    Score difference  validation
# 0          0.494881       False
# 1          0.414586       False
# 2          0.571841       False
# 3          0.482462       False
# 4          0.483268       False

# %%
grn_validate
# Out:
#        TF         TG  genie3_score  GRNBoost2_score  Average Score  \
# 0     trh        btl       0.53280         0.179085       0.355942
# 1     srp      eater       0.42477         0.341123       0.382946
# 2     grh         ed       0.40212         0.390755       0.396437
# 3     grh     Cad86C       0.37534         0.263124       0.319232
# 4     ato       sens       0.35251         0.325354       0.338932
# ...   ...        ...           ...              ...            ...
# 3698  pho        pnr       0.00002         0.000213       0.000116
# 3699  grh  yellow-e2       0.00002         0.002221       0.001121
# 3700   dl        Ubx       0.00002         0.000855       0.000438
# 3701  pho       MED7       0.00001         0.000698       0.000354
# 3702   en    CG15717       0.00001         0.036443       0.018227
#
#       Score difference
# 0             0.353715
# 1             0.083647
# 2             0.011365
# 3             0.112216
# 4             0.027156
# ...                ...
# 3698          0.000193
# 3699          0.002201
# 3700          0.000835
# 3701          0.000688
# 3702          0.036433
#
# [3703 rows x 6 columns]

# %%
grn_val_sort = grn_validate.sort_values(by=['Average Score'],ascending=False).reset_index()
grn_val_sort.head(10)
# Out:
#    index    TF          TG  genie3_score  GRNBoost2_score  Average Score  \
# 0      2   grh          ed       0.40212         0.390755       0.396437
# 1      9  Dref         mts       0.31779         0.450414       0.384102
# 2      1   srp       eater       0.42477         0.341123       0.382946
# 3      6    ab          ko       0.34260         0.418111       0.380356
# 4      0   trh         btl       0.53280         0.179085       0.355942
# 5     15   pho      Tsp96F       0.27011         0.440703       0.355407
# 6      5   grh         uif       0.34386         0.365074       0.354467
# 7      4   ato        sens       0.35251         0.325354       0.338932
# 8      7    so  betaTub60D       0.33838         0.338161       0.338271
# 9     48    so        Mmp2       0.15982         0.481669       0.320744
#
#    Score difference
# 0          0.011365
# 1          0.132624
# 2          0.083647
# 3          0.075511
# 4          0.353715
# 5          0.170593
# 6          0.021214
# 7          0.027156
# 8          0.000219
# 9          0.321849

# %%
len(grn_val_sort)
# Out:
# 3703

# %%
## GENIE3 and TFLINK validation
genie3_val = pd.merge(genie3_df, tfLink_df2, how='inner', on=['TF','TG'])

# %%
genie3_val_sort = genie3_val.sort_values(by=['score'],ascending=False).reset_index()
genie3_val_sort.head(10)
# Out:
#    index    TF          TG    score
# 0      0   trh         btl  0.53280
# 1      1   srp       eater  0.42477
# 2      2   grh          ed  0.40212
# 3      3   grh      Cad86C  0.37534
# 4      4   ato        sens  0.35251
# 5      5   grh         uif  0.34386
# 6      6    ab          ko  0.34260
# 7      7    so  betaTub60D  0.33838
# 8      8   twi     meso18E  0.32094
# 9      9  Dref         mts  0.31779

# %%
## GRNBoost2 TFLink Validation
grnBoost2_val = pd.merge(GRNBoost2_df, tfLink_df2, how='inner', on=['TF','TG'])
grnBoost2_val_sort = grnBoost2_val.sort_values(by=['Score'],ascending=False).reset_index()

# %%
grnBoost2_val_sort.head(10)
# Out:
#    index     TF       TG     Score
# 0      0     so       fw  0.502905
# 1      1     so     Mmp2  0.481669
# 2      2  Cp190  Su(z)12  0.465833
# 3      3    chn       px  0.451328
# 4      4   Dref      mts  0.450414
# 5      5    pho   Tsp96F  0.440703
# 6      6   Dref    Tap42  0.438787
# 7      7   Dref     sina  0.421007
# 8      8  Cp190      ssx  0.420298
# 9      9     ab       ko  0.418111

# %% [markdown]
# ### Comparison between TFLink and BioGRN datasets

# %%
print('BioGRN Validated TFs: ', len(grn_val_sort['TF'].value_counts()))
print('BioGRN Validated Links: ', len(grn_val_sort))
print('Total BioGRN generated predictions: ', len(bioGRN))

biogrn_accuracy = round(len(grn_val_sort)/len(bioGRN) * 100, 2)
print('Validation Accuracy: ', biogrn_accuracy, ' %')
# Out:
# BioGRN Validated TFs:  131
# BioGRN Validated Links:  3703
# Total BioGRN generated predictions:  534843
# Validation Accuracy:  0.69  %

# %%
print('GENIE3 Validated TFs: ', len(genie3_val_sort['TF'].value_counts()))
print('GENIE3 Validated Links: ', len(genie3_val_sort))
print('Total GENIE3 generated predictions: ', len(genie3_df))

genie3_accuracy = round(len(genie3_val_sort)/len(genie3_df) * 100, 2)
print('Validation Accuracy: ', genie3_accuracy, ' %')
# Out:
# GENIE3 Validated TFs:  132
# GENIE3 Validated Links:  3846
# Total GENIE3 generated predictions:  579908
# Validation Accuracy:  0.66  %

# %%
print('GRNBoost2 Validated TFs: ', len(grnBoost2_val_sort['TF'].value_counts()))
print('GRNBoost2 Validated Links: ', len(grnBoost2_val_sort))
print('Total GRNBoost2 generated predictions: ', len(GRNBoost2_df))

grnBoost2_accuracy = round(len(grnBoost2_val_sort)/len(GRNBoost2_df) * 100, 2)
print('Validation Accuracy: ', grnBoost2_accuracy, ' %')
# Out:
# GRNBoost2 Validated TFs:  211
# GRNBoost2 Validated Links:  28957
# Total GRNBoost2 generated predictions:  4879738
# Validation Accuracy:  0.59  %

# %%
# grn_val_sort.iloc[0:21,:].to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/grn_val_sort_20.csv')

# %%
# grn_val_sort.to_excel('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/validated_regulatory_links.xlsx')

# %%
# genie3_val_sort.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/genie3_val.csv')
# grnBoost2_val_sort.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/grnBoost2_val.csv')

# %%
# genie3_val_sort.iloc[0:21,:].to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/genie3_val_20.csv')
# grnBoost2_val_sort.iloc[0:21,:].to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/grnBoost2_val_20.csv')

# %%
# bioGRN.to_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/bioGRN_validate.csv')

# %%
# bioGRN    = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/BioGRN_All.csv', sep=',')
# tfLink_df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Final_Datasets/Outputs/TFLINK_Drosophila.tsv', sep='\t')
# tfLink_df2 = tfLink_df.iloc[:,4:6]
